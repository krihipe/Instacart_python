# %% [markdown]
# #01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Exercise 4.6 - STEP 3: In a new notebook, import the orders_products_combined dataframe from the pickle fle you just saved.

# %% [markdown]
# #02. Importing data

# %%
path = r'/Users/kristincpeterson/Desktop/DataAnalytics/Achievement_4/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/kristincpeterson/Desktop/DataAnalytics/Achievement_4/Instacart Basket Analysis'

# %%
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02_Data', 'Prepared_Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## STEP 4: Check the shape of the imported dataframe (it should be the same as the one you exported)

# %%
# Checking the rows and columns of df_ords_prods_combined

df_ords_prods_combined.shape
# Out:
# (32434489, 13)

# %% [markdown]
# #### The shape of the imported dataframe matches what was exported.

# %% [markdown]
# ## STEP 5: Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you're using your wrangled, cleaned, and deduped products data set stored in your "Prepared Data" folder from the previous Exercise's task.

# %%
# Importing products_checked.csv from Prepared Data folder

df_prods = pd.read_csv(os.path.join(path, '02_Data', 'Prepared_Data', 'products_checked.csv'), index_col = False)

# %%
# Checking the rows and columns of df_prods

df_prods.shape
# Out:
# (49693, 6)

# %%
# Checking the head of df_prods

df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Checking the head of df_ords_prods_combined

df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                  2                  8                     NaN         196
# 1                  2                  8                     NaN       14084
# 2                  2                  8                     NaN       12427
# 3                  2                  8                     NaN       26088
# 4                  2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
# Merging the df_prods and df_ords_prods_combined dataframes using product_id as a key

df_ords_prods_merged = df_prods.merge(df_ords_prods_combined, on = ['product_id'])

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0                    0           1  Chocolate Sandwich Cookies        61
# 1                    0           1  Chocolate Sandwich Cookies        61
# 2                    0           1  Chocolate Sandwich Cookies        61
# 3                    0           1  Chocolate Sandwich Cookies        61
# 4                    0           1  Chocolate Sandwich Cookies        61
# ...                ...         ...                         ...       ...
# 32434207         49692       49688      Fresh Foaming Cleanser        73
# 32434208         49692       49688      Fresh Foaming Cleanser        73
# 32434209         49692       49688      Fresh Foaming Cleanser        73
# 32434210         49692       49688      Fresh Foaming Cleanser        73
# 32434211         49692       49688      Fresh Foaming Cleanser        73
#
#           department_id  prices  Unnamed: 0.1  Unnamed: 0_y  order_id  \
# ...

# %% [markdown]
# ## STEP 6: Confirm the results of the merge using the merge flag.

# %%
# Checking the values in the merge column

df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Drop unnamed columns in df_ords_prods_merged (not necessary) 

df_ords_prods_merged = df_ords_prods_merged.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0.1', 'Unnamed: 0_y', '_merge'])

# %%
df_ords_prods_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32434207       49688      Fresh Foaming Cleanser        73             11
# 32434208       49688      Fresh Foaming Cleanser        73             11
# 32434209       49688      Fresh Foaming Cleanser        73             11
# 32434210       49688      Fresh Foaming Cleanser        73             11
# 32434211       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id eval_set  order_number  order_day_of_week  \
# ...

# %%
# Checking the rows and columns of df_ords_prods_merged

df_ords_prods_merged.shape
# Out:
# (32434212, 14)

# %% [markdown]
# ## STEP 7: Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
# Export data to pkl

df_ords_prods_merged.to_pickle(os.path.join(path, '02_Data', 'Prepared_Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## STEP 8: Ensure your notebooks and Instacart folder are organized and that comments and section headings have been used throughout your code. All your exported data files should be effectively labeled and stored in your "Data" folder.
